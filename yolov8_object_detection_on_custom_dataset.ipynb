# %% [markdown]
# ## Packages

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Xeno\Projects\Automatic-Number-Plate-Recognition-Using-Yolov8-and-OCR

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20  Python-3.10.0 torch-2.3.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# Setup complete  (16 CPUs, 15.7 GB RAM, 365.0/456.7 GB disk)

# %%
# Git clone method (for development)

# %cd {HOME}
# !git clone github.com/ultralytics/ultralytics
# %cd {HOME}/ultralytics
# !pip install -qe ultralytics

# from IPython import display
# display.clear_output()

# import ultralytics
# ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# c:\Xeno\Projects\Automatic-Number-Plate-Recognition-Using-Yolov8-and-OCR
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
#
#   0%|          | 0.00/6.23M [00:00<?, ?B/s]
#  48%|████▊     | 3.00M/6.23M [00:00<00:00, 31.4MB/s]
#  96%|█████████▋| 6.00M/6.23M [00:00<00:00, 21.0MB/s]
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 20.3MB/s]
#
# Ultralytics YOLOv8.0.20  Python-3.10.0 torch-2.3.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to dog.jpeg...
#
#   0%|          | 0.00/104k [00:00<?, ?B/s]
# 100%|██████████| 104k/104k [00:00<00:00, 2.21MB/s]
# image 1/1 C:\Xeno\Projects\Automatic-Number-Plate-Recognition-Using-Yolov8-and-OCR\dog.jpeg: 640x384 1 person, 1 car, 1 dog, 177.8ms
# Speed: 4.0ms pre-process, 177.8ms inference, 305.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict

# %% [markdown]
# ## Custom Training

# %%
import tensorflow as tf

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !pip list
# Out:
# Package                                      Version              Editable project location
# -------------------------------------------- -------------------- ------------------------------------
# absl-py                                      1.4.0
# aiofiles                                     23.2.1
# aiohttp                                      3.9.5
# aiosignal                                    1.3.1
# altair                                       5.3.0
# annotated-types                              0.6.0
# anyio                                        4.2.0
# apache-beam                                  2.46.0
# appdirs                                      1.4.4
# argon2-cffi                                  23.1.0
# argon2-cffi-bindings                         21.2.0
# array-record                                 0.4.1
# arrow                                        1.3.0
# asgiref                                      3.8.1
# asttokens                                    2.4.1
# astunparse                                   1.6.3
# async-lru                                    2.0.4
# async-timeout                                4.0.3
# attrs                                        23.2.0
# audioread                                    3.0.1
# avro-python3                                 1.10.2
# Babel                                        2.15.0
# backcall                                     0.2.0
# bcrypt                                       4.1.3
# beautifulsoup4                               4.12.3
# bentoml                                      1.2.18
# bleach                                       6.1.0
# blinker                                      1.7.0
# boto3                                        1.34.130
# botocore                                     1.34.130
# Brotli                                       1.1.0
# bs4                                          0.0.2
# build                                        1.2.1
# CacheControl                                 0.14.0
# cachetools                                   5.3.2
# cattrs                                       23.1.2
# certifi                                      2023.11.17
# cffi                                         1.16.0
# charset-normalizer                           3.3.2
# circus                                       0.18.0
# click                                        8.1.7
# click-option-group                           0.5.6
# cloudpickle                                  2.2.1
# colorama                                     0.4.6
# comm                                         0.2.1
# contextlib2                                  21.6.0
# contourpy                                    1.2.0
# crcmod                                       1.7
# cryptography                                 42.0.5
# cvzone                                       1.6.1
# cycler                                       0.12.1
# Cython                                       3.0.8
# datasets                                     2.20.0
# debugpy                                      1.8.0
# decorator                                    5.1.1
# deepmerge                                    1.1.1
# defusedxml                                   0.7.1
# Deprecated                                   1.2.14
# dill                                         0.3.8
# dm-tree                                      0.1.8
# dnspython                                    2.6.1
# docopt                                       0.6.2
# easyocr                                      1.7.1
# email_validator                              2.2.0
# ensure                                       1.0.2
# et-xmlfile                                   1.1.0
# etils                                        1.6.0
# exceptiongroup                               1.2.0
# executing                                    2.0.1
# fastapi                                      0.111.0
# fastapi-cli                                  0.0.4
# fastavro                                     1.9.3
# fasteners                                    0.19
# fastjsonschema                               2.19.1
# ffmpy                                        0.3.2
# filelock                                     3.15.1
# firebase                                     4.0.1
# firebase-admin                               6.4.0
# Flask                                        3.0.1
# Flask-Bcrypt                                 1.0.1
# flatbuffers                                  23.5.26
# fonttools                                    4.47.2
# fqdn                                         1.5.1
# frozenlist                                   1.4.1
# fs                                           2.4.16
# fsspec                                       2023.12.2
# gast                                         0.4.0
# gcloud                                       0.18.3
# gensim                                       4.3.2
# gin-config                                   0.5.0
# google-api-core                              2.16.1
# google-api-python-client                     2.116.0
# google-auth                                  2.27.0
# google-auth-httplib2                         0.2.0
# google-auth-oauthlib                         0.4.6
# google-cloud-core                            2.4.1
# google-cloud-firestore                       2.15.0
# google-cloud-storage                         2.14.0
# google-crc32c                                1.5.0
# google-pasta                                 0.2.0
# google-resumable-media                       2.7.0
# googleapis-common-protos                     1.62.0
# gradio                                       3.50.2
# gradio_client                                0.6.1
# grpcio                                       1.62.0
# grpcio-status                                1.62.0
# h11                                          0.14.0
# h5py                                         3.10.0
# hdfs                                         2.7.3
# httpcore                                     1.0.5
# httplib2                                     0.21.0
# httptools                                    0.6.1
# httpx                                        0.27.0
# httpx-ws                                     0.6.0
# huggingface-hub                              0.23.4
# idna                                         3.6
# imageio                                      2.34.2
# immutabledict                                4.1.0
# importlib-metadata                           6.11.0
# importlib-resources                          6.1.1
# inflate64                                    1.0.0
# inflection                                   0.5.1
# intel-openmp                                 2021.4.0
# ipykernel                                    6.29.0
# ipython                                      8.12.3
# isoduration                                  20.11.0
# itsdangerous                                 2.1.2
# jax                                          0.4.30
# jaxlib                                       0.4.30
# jedi                                         0.19.1
# Jinja2                                       3.1.2
# jmespath                                     1.0.1
# joblib                                       1.3.2
# json5                                        0.9.25
# jsonpointer                                  3.0.0
# jsonschema                                   4.21.1
# jsonschema-specifications                    2023.12.1
# jupyter_client                               8.6.0
# jupyter_core                                 5.7.1
# jupyter-events                               0.10.0
# jupyter-lsp                                  2.2.5
# jupyter_server                               2.14.1
# jupyter_server_terminals                     0.5.3
# jupyterlab                                   4.2.2
# jupyterlab_pygments                          0.3.0
# jupyterlab_server                            2.27.2
# jwcrypto                                     1.5.6
# kaggle                                       1.6.4
# keras                                        2.10.0
# Keras-Preprocessing                          1.1.2
# kiwisolver                                   1.4.5
# labelImg                                     1.8.6
# lazy_loader                                  0.4
# libclang                                     16.0.6
# librosa                                      0.10.1
# llvmlite                                     0.42.0
# lvis                                         0.5.3
# lxml                                         5.1.0
# Markdown                                     3.5.2
# markdown-it-py                               3.0.0
# MarkupSafe                                   2.1.4
# matplotlib                                   3.8.2
# matplotlib-inline                            0.1.6
# mdurl                                        0.1.2
# mediapipe                                    0.10.14
# mistune                                      3.0.2
# mkl                                          2021.4.0
# ml-dtypes                                    0.3.2
# MouseInfo                                    0.1.3
# mpmath                                       1.3.0
# msgpack                                      1.0.7
# multidict                                    6.0.5
# multiprocess                                 0.70.16
# multivolumefile                              0.2.3
# mypy-boto3-s3                                1.34.120
# mysql                                        0.0.3
# mysql-connector                              2.2.9
# mysqlclient                                  2.2.4
# namex                                        0.0.7
# nbclient                                     0.10.0
# nbconvert                                    7.16.2
# nbformat                                     5.10.3
# nest-asyncio                                 1.6.0
# networkx                                     3.3
# ninja                                        1.11.1.1
# nltk                                         3.8.1
# notebook                                     7.2.1
# notebook_shim                                0.2.4
# numba                                        0.59.0
# numpy                                        1.24.4
# nvidia-ml-py                                 11.525.150
# oauth2client                                 4.1.3
# oauthlib                                     3.2.2
# object-detection                             0.1
# objsize                                      0.6.1
# opencv-contrib-python                        4.10.0.84
# opencv-python                                4.9.0.80
# opencv-python-headless                       4.9.0.80
# openpyxl                                     3.1.2
# opentelemetry-api                            1.20.0
# opentelemetry-instrumentation                0.41b0
# opentelemetry-instrumentation-aiohttp-client 0.41b0
# opentelemetry-instrumentation-asgi           0.41b0
# opentelemetry-sdk                            1.20.0
# opentelemetry-semantic-conventions           0.41b0
# opentelemetry-util-http                      0.41b0
# opt-einsum                                   3.3.0
# orjson                                       3.9.12
# outcome                                      1.3.0.post0
# overrides                                    7.7.0
# packaging                                    23.2
# pandas                                       2.2.0
# pandocfilters                                1.5.1
# parso                                        0.8.3
# pathspec                                     0.12.1
# pickleshare                                  0.7.5
# pillow                                       10.2.0
# pip                                          24.0
# pip-requirements-parser                      32.0.1
# pip-tools                                    7.4.1
# pipreqs                                      0.5.0
# platformdirs                                 4.2.0
# pooch                                        1.8.1
# portalocker                                  2.8.2
# prometheus_client                            0.20.0
# promise                                      2.3
# prompt-toolkit                               3.0.43
# proto-plus                                   1.23.0
# protobuf                                     3.19.6
# psutil                                       5.9.8
# pure-eval                                    0.2.2
# py-cpuinfo                                   9.0.0
# py7zr                                        0.21.0
# pyarrow                                      16.1.0
# pyarrow-hotfix                               0.6
# pyasn1                                       0.5.1
# pyasn1-modules                               0.3.0
# PyAutoGUI                                    0.9.54
# pybcj                                        1.0.2
# pyclipper                                    1.3.0.post5
# pycocotools                                  2.0.7
# pycparser                                    2.21
# pycryptodome                                 3.20.0
# pycryptodomex                                3.20.0
# pydantic                                     1.10.11
# pydantic_core                                2.20.1
# pydot                                        1.4.2
# pydub                                        0.25.1
# pyforest                                     1.1.0
# PyGetWindow                                  0.0.9
# Pygments                                     2.17.2
# PyJWT                                        2.8.0
# pymongo                                      3.13.0
# PyMsgBox                                     1.0.9
# pyparsing                                    2.4.7
# pyperclip                                    1.9.0
# pyppmd                                       1.1.0
# pyproject_hooks                              1.1.0
# PyQt5                                        5.15.10
# PyQt5-Qt5                                    5.15.2
# PyQt5_sip                                    12.15.0
# Pyrebase4                                    4.7.1
# PyRect                                       0.2.0
# PyScreeze                                    0.1.30
# PySocks                                      1.7.1
# pytesseract                                  0.3.10
# python-bidi                                  0.4.2
# python-box                                   6.0.2
# python-dateutil                              2.8.2
# python-dotenv                                1.0.1
# python-json-logger                           2.0.7
# python-jwt                                   4.1.0
# python-multipart                             0.0.9
# python-slugify                               8.0.2
# pytweening                                   1.2.0
# pytz                                         2023.4
# pywin32                                      306
# pywinpty                                     2.0.13
# pyxlsb                                       1.0.10
# PyYAML                                       5.3.1
# pyzmq                                        25.1.2
# pyzstd                                       0.16.0
# referencing                                  0.34.0
# regex                                        2023.12.25
# requests                                     2.32.3
# requests-oauthlib                            1.3.1
# requests-toolbelt                            0.10.1
# rfc3339-validator                            0.1.4
# rfc3986-validator                            0.1.1
# rich                                         13.7.0
# rouge_score                                  0.1.2
# rpds-py                                      0.18.0
# rsa                                          4.9
# ruff                                         0.4.9
# s3transfer                                   0.10.1
# sacrebleu                                    2.2.0
# safetensors                                  0.4.3
# schema                                       0.7.7
# scikit-image                                 0.24.0
# scikit-learn                                 1.4.0
# scipy                                        1.12.0
# seaborn                                      0.13.2
# selenium                                     4.17.2
# semantic-version                             2.10.0
# Send2Trash                                   1.8.3
# sentencepiece                                0.2.0
# sentry-sdk                                   2.9.0
# seqeval                                      1.2.2
# setuptools                                   69.5.1
# shapely                                      2.0.4
# shellingham                                  1.5.4
# simple-di                                    0.1.5
# six                                          1.16.0
# smart-open                                   7.0.4
# sniffio                                      1.3.0
# sortedcontainers                             2.4.0
# sounddevice                                  0.4.7
# soundfile                                    0.12.1
# soupsieve                                    2.5
# soxr                                         0.3.7
# stack-data                                   0.6.3
# starlette                                    0.37.2
# sympy                                        1.12.1
# tabulate                                     0.9.0
# tbb                                          2021.12.0
# tensorboard                                  2.10.1
# tensorboard-data-server                      0.6.1
# tensorboard-plugin-wit                       1.8.1
# tensorflow                                   2.10.1
# tensorflow-addons                            0.22.0
# tensorflow-datasets                          4.9.4
# tensorflow-estimator                         2.10.0
# tensorflow-hub                               0.16.1
# tensorflow-io                                0.31.0
# tensorflow-io-gcs-filesystem                 0.31.0
# tensorflow-metadata                          1.13.0
# tensorflow-model-optimization                0.7.5
# tensorflow-text                              2.10.0
# termcolor                                    2.4.0
# terminado                                    0.18.1
# text-unidecode                               1.3
# textSummarizer                               0.0.0                c:\xeno\projects\text-summarizer\src
# texttable                                    1.7.0
# tf-keras                                     2.15.0
# tf_keras-nightly                             2.16.0.dev2024013010
# tf-models-official                           2.10.1
# tf-slim                                      1.1.0
# thop                                         0.1.1.post2209072238
# threadpoolctl                                3.2.0
# tifffile                                     2024.7.2
# tinycss2                                     1.2.1
# tokenizers                                   0.19.1
# toml                                         0.10.2
# tomli                                        2.0.1
# tomli_w                                      1.0.0
# tomlkit                                      0.12.0
# toolz                                        0.12.1
# torch                                        2.3.1+cu118
# torchaudio                                   2.3.1+cu118
# torchvision                                  0.18.1+cu118
# tornado                                      6.4
# tqdm                                         4.66.4
# traitlets                                    5.14.1
# transformers                                 4.41.2
# trio                                         0.24.0
# trio-websocket                               0.11.1
# typeguard                                    2.13.3
# typer                                        0.12.3
# types-python-dateutil                        2.9.0.20240316
# typing_extensions                            4.9.0
# tzdata                                       2023.4
# ujson                                        5.10.0
# ultralytics                                  8.0.20
# ultralytics-thop                             2.0.0
# uri-template                                 1.3.0
# uritemplate                                  4.1.1
# urllib3                                      2.2.2
# utils                                        1.0.2
# uvicorn                                      0.18.3
# watchfiles                                   0.22.0
# wcwidth                                      0.2.13
# webcolors                                    24.6.0
# webencodings                                 0.5.1
# websocket-client                             1.8.0
# websockets                                   11.0.3
# Werkzeug                                     3.0.1
# wget                                         3.2
# wheel                                        0.42.0
# wrapt                                        1.14.1
# wsproto                                      1.2.0
# xlrd                                         2.0.1
# xxhash                                       3.4.1
# yarg                                         0.1.9
# yarl                                         1.9.4
# zipp                                         3.17.0
# zstandard                                    0.22.0
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\smitg\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Make sure the correct GPU is selected

# %%
import torch
print(torch.cuda.is_available())  # Should return True if GPU is available
print(torch.cuda.get_device_name(0))  # Should print the name of your GPU
# Out:
# True
# NVIDIA GeForce RTX 3060 Laptop GPU

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=dataset/data.yaml epochs=100 imgsz=800 device=0 batch=16 plots=True
# Out:
# c:\Xeno\Projects\Automatic-Number-Plate-Recognition-Using-Yolov8-and-OCR
# Ultralytics YOLOv8.0.20  Python-3.10.0 torch-2.3.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# yolo\engine\trainer: task=detect, mode=train, model=yolov8s.yaml, data=dataset/data.yaml, epochs=100, patience=50, batch=16, imgsz=800, save=True, cache=False, device=0, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs\detect\train15
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.Detect                [1, [128, 256, 512]]
# Model summary: 225 layers, 11135987 parameters, 11135971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
#
# train: Scanning C:\Xeno\Projects\Automatic-Number-Plate-Recognition-Using-Yolov8-and-OCR\dataset\labels\training.cache... 47 images, 1 backgrounds, 0 corrupt: 100%|██████████| 47/47 [00:00<?, ?it/s]
# train: Scanning C:\Xeno\Projects\Automatic-Number-Plate-Recognition-Using-Yolov8-and-OCR\dataset\labels\training.cache... 47 images, 1 backgrounds, 0 corrupt: 100%|██████████| 47/47 [00:00<?, ?it/s]
#
# val: Scanning C:\Xeno\Projects\Automatic-Number-Plate-Recognition-Using-Yolov8-and-OCR\dataset\labels\validation.cache... 47 images, 1 backgrounds, 0 corrupt: 100%|██████████| 47/47 [00:00<?, ?it/s]
# val: Scanning C:\Xeno\Projects\Automatic-Number-Plate-Recognition-Using-Yolov8-and-OCR\dataset\labels\validation.cache... 47 images, 1 backgrounds, 0 corrupt: 100%|██████████| 47/47 [00:00<?, ?it/s]
# Image sizes 800 train, 800 val
# Using 8 dataloader workers
# Logging results to runs\detect\train15
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#       1/100      6.09G      2.933      13.84      2.141         32        800:   0%|          | 0/3 [00:20<?, ?it/s]
#       1/100      6.09G      2.933      13.84      2.141         32        800:  33%|███▎      | 1/3 [00:20<00:41, 20.73s/it]Exception in thread Thread-6 (plot_images):
# Traceback (most recent call last):
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 99, in run
#     return _run_old_run_func()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 94, in _run_old_run_func
#     reraise(*_capture_exception())
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\utils.py", line 1642, in reraise
#     raise value
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 92, in _run_old_run_func
#     return old_run_func(self, *a, **kw)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 251, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 63, in box_label
#     w, h = self.font.getsize(label)  # text width, height (WARNING: deprecated) in 9.2.0
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
#
#       1/100      6.09G      3.021       17.2      2.095         20        800:  33%|███▎      | 1/3 [00:21<00:41, 20.73s/it]
#       1/100      6.09G      3.021       17.2      2.095         20        800:  67%|██████▋   | 2/3 [00:21<00:09,  9.08s/it]Exception in thread Thread-7 (plot_images):
# Traceback (most recent call last):
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 99, in run
#     return _run_old_run_func()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 94, in _run_old_run_func
#     reraise(*_capture_exception())
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\utils.py", line 1642, in reraise
#     raise value
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 92, in _run_old_run_func
#     return old_run_func(self, *a, **kw)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 251, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 63, in box_label
#     w, h = self.font.getsize(label)  # text width, height (WARNING: deprecated) in 9.2.0
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
#
#       1/100      6.09G      3.046      17.33      2.127         30        800:  67%|██████▋   | 2/3 [00:22<00:09,  9.08s/it]
#       1/100      6.09G      3.046      17.33      2.127         30        800: 100%|██████████| 3/3 [00:22<00:00,  5.32s/it]Exception in thread Thread-8 (plot_images):
# Traceback (most recent call last):
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib
/it]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 1/2 [00:19<00:19, 19.67s/it]Exception in thread Thread-310 (plot_images):
# Traceback (most recent call last):
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 99, in run
#     return _run_old_run_func()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 94, in _run_old_run_func
#     reraise(*_capture_exception())
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\utils.py", line 1642, in reraise
#     raise value
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 92, in _run_old_run_func
#     return old_run_func(self, *a, **kw)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 251, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 63, in box_label
#     w, h = self.font.getsize(label)  # text width, height (WARNING: deprecated) in 9.2.0
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
# Exception in thread Thread-311 (plot_images):
# Traceback (most recent call last):
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 99, in run
#     return _run_old_run_func()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 94, in _run_old_run_func
#     reraise(*_capture_exception())
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\utils.py", line 1642, in reraise
#     raise value
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 92, in _run_old_run_func
#     return old_run_func(self, *a, **kw)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 251, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 63, in box_label
#     w, h = self.font.getsize(label)  # text width, height (WARNING: deprecated) in 9.2.0
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:20<00:00,  8.30s/it]Exception in thread Thread-312 (plot_images):
# Traceback (most recent call last):
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 99, in run
#     return _run_old_run_func()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 94, in _run_old_run_func
#     reraise(*_capture_exception())
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\utils.py", line 1642, in reraise
#     raise value
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 92, in _run_old_run_func
#     return old_run_func(self, *a, **kw)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 251, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 63, in box_label
#     w, h = self.font.getsize(label)  # text width, height (WARNING: deprecated) in 9.2.0
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
# Exception in thread Thread-313 (plot_images):
# Traceback (most recent call last):
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 99, in run
#     return _run_old_run_func()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 94, in _run_old_run_func
#     reraise(*_capture_exception())
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\utils.py", line 1642, in reraise
#     raise value
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 92, in _run_old_run_func
#     return old_run_func(self, *a, **kw)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 251, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 63, in box_label
#     w, h = self.font.getsize(label)  # text width, height (WARNING: deprecated) in 9.2.0
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:22<00:00, 11.41s/it]
#                    all         47         46      0.999          1      0.995      0.836
#
# 100 epochs completed in 1.260 hours.
# Optimizer stripped from runs\detect\train15\weights\last.pt, 22.5MB
# Optimizer stripped from runs\detect\train15\weights\best.pt, 22.5MB
#
# Validating runs\detect\train15\weights\best.pt...
# Ultralytics YOLOv8.0.20  Python-3.10.0 torch-2.3.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 1/2 [00:18<00:18, 18.31s/it]Exception in thread Thread-316 (plot_images):
# Traceback (most recent call last):
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 99, in run
#     return _run_old_run_func()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 94, in _run_old_run_func
#     reraise(*_capture_exception())
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\utils.py", line 1642, in reraise
#     raise value
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 92, in _run_old_run_func
#     return old_run_func(self, *a, **kw)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 251, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 63, in box_label
#     w, h = self.font.getsize(label)  # text width, height (WARNING: deprecated) in 9.2.0
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
# Exception in thread Thread-317 (plot_images):
# Traceback (most recent call last):
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 99, in run
#     return _run_old_run_func()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 94, in _run_old_run_func
#     reraise(*_capture_exception())
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\utils.py", line 1642, in reraise
#     raise value
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 92, in _run_old_run_func
#     return old_run_func(self, *a, **kw)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 251, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 63, in box_label
#     w, h = self.font.getsize(label)  # text width, height (WARNING: deprecated) in 9.2.0
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:18<00:00,  7.73s/it]Exception in thread Thread-318 (plot_images):
# Traceback (most recent call last):
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 99, in run
#     return _run_old_run_func()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 94, in _run_old_run_func
#     reraise(*_capture_exception())
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\utils.py", line 1642, in reraise
#     raise value
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 92, in _run_old_run_func
#     return old_run_func(self, *a, **kw)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 251, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 63, in box_label
#     w, h = self.font.getsize(label)  # text width, height (WARNING: deprecated) in 9.2.0
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
# Exception in thread Thread-319 (plot_images):
# Traceback (most recent call last):
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 99, in run
#     return _run_old_run_func()
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 94, in _run_old_run_func
#     reraise(*_capture_exception())
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\utils.py", line 1642, in reraise
#     raise value
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\sentry_sdk\integrations\threading.py", line 92, in _run_old_run_func
#     return old_run_func(self, *a, **kw)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 251, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "C:\Users\smitg\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\yolo\utils\plotting.py", line 63, in box_label
#     w, h = self.font.getsize(label)  # text width, height (WARNING: deprecated) in 9.2.0
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:21<00:00, 10.75s/it]
#                    all         47         46      0.998          1      0.995      0.834
# Speed: 0.9ms pre-process, 7.1ms inference, 0.0ms loss, 2.3ms post-process per image
# Results saved to runs\detect\train15
# Sentry is attempting to send 1 pending events
# Waiting up to 2 seconds
# Press Ctrl-Break to quit
